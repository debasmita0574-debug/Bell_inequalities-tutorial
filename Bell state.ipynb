# %% [markdown]
# <a href="https://colab.research.google.com/github/debasmita0574-debug/Bell_inequalities-tutorial/blob/main/Bell%20state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bell State: |Φ⁺⟩
#
# In this notebook, we generate the Bell state:
# (|00⟩ + |11⟩) / √2
# This is the simplest example of quantum entanglement.

# %%
# !pip install qiskit qiskit-aer pylatexenc --quiet
